# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\kilar\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\kilar\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\kilar\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kilar\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\kilar\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\kilar\appdata\roaming\python\python311\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kilar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
corpus ="""Hello Welcome to NLP course. Please do watch the course and practice code"""
corpus
# Out:
# 'Hello Welcome to NLP course. Please do watch the course and practice code'

# %%
# paragraph to sentence
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(corpus)
sentences
# Out:
# ['Hello Welcome to NLP course.',
#  'Please do watch the course and practice code']

# %%
#paragraph to words
from nltk.tokenize import word_tokenize
words = word_tokenize(corpus)
words
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'course',
#  'and',
#  'practice',
#  'code']

# %%
#sentence to words
words_2 = []
for sent in sentences:
    words = word_tokenize(sent)
    words_2.extend(words)
words_2
# Out:
# ['Hello',
#  'Welcome',
#  'to',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'course',
#  'and',
#  'practice',
#  'code']

# %%
#sentence to words
paragraph = "".join(sentences)
print(word_tokenize(paragraph))
# Out:
# ['Hello', 'Welcome', 'to', 'NLP', 'course.Please', 'do', 'watch', 'the', 'course', 'and', 'practice', 'code']
