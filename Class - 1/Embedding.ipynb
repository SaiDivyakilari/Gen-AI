# %% [markdown]
# Word2Vec

# %%
from gensim.models import Word2Vec

# %%
documents = [
    "The cat sat on the mat.",
    "The dog barked loudly at night.",
    "The bird built a nest in the tree.",
    "A lion lives in the jungle.",
    "Elephants are the largest land animals.",
    "The teacher wrote notes on the board.",
    "Students completed their homework before class.",
    "The professor explained deep learning algorithms.",
    "Artificial intelligence powers many modern applications.",
    "Machine learning models require quality data.",
    "Python is easy to learn.",
    "SQL is used to query databases.",
    "Pandas simplifies data analysis tasks.",
    "NumPy provides efficient numerical operations.",
    "Data visualization helps identify trends.",
    "The software engineer deployed the application.",
    "The developer fixed the production bug.",
    "Cloud computing offers scalable infrastructure.",
    "Cybersecurity protects sensitive information.",
    "The server handled thousands of requests.",
    "The doctor examined the patient carefully.",
    "Healthy food improves overall well-being.",
    "Regular exercise keeps the body fit.",
    "The nurse checked the patient's temperature.",
    "The hospital installed new medical equipment.",
    "The chef prepared spicy Indian curry.",
    "Fresh vegetables are rich in nutrients.",
    "The customer ordered biryani for dinner.",
    "The restaurant served delicious desserts.",
    "Coffee tastes better when freshly brewed.",
    "The football team won the championship.",
    "Basketball players trained every morning.",
    "The athlete completed the marathon.",
    "Swimming improves cardiovascular fitness.",
    "The coach motivated the entire team.",
    "The company hired a new manager.",
    "Employees attended the weekly meeting.",
    "Sales increased during the holiday season.",
    "Marketing campaigns attracted new customers.",
    "The startup secured funding from investors.",
    "Heavy rain flooded several streets.",
    "The sun shines brightly in summer.",
    "Snow covered the mountains during winter.",
    "The wind moved the tree branches.",
    "People enjoyed the pleasant weather.",
    "The family traveled to Arizona for vacation.",
    "Children played in the playground.",
    "The movie received excellent reviews.",
    "Music makes people feel relaxed.",
    "Technology continues to evolve rapidly."
]

# %%
tokenized_docs = [doc.lower().split()for doc in documents]
tokenized_docs
# Out:
# [['the', 'cat', 'sat', 'on', 'the', 'mat.'],
#  ['the', 'dog', 'barked', 'loudly', 'at', 'night.'],
#  ['the', 'bird', 'built', 'a', 'nest', 'in', 'the', 'tree.'],
#  ['a', 'lion', 'lives', 'in', 'the', 'jungle.'],
#  ['elephants', 'are', 'the', 'largest', 'land', 'animals.'],
#  ['the', 'teacher', 'wrote', 'notes', 'on', 'the', 'board.'],
#  ['students', 'completed', 'their', 'homework', 'before', 'class.'],
#  ['the', 'professor', 'explained', 'deep', 'learning', 'algorithms.'],
#  ['artificial', 'intelligence', 'powers', 'many', 'modern', 'applications.'],
#  ['machine', 'learning', 'models', 'require', 'quality', 'data.'],
#  ['python', 'is', 'easy', 'to', 'learn.'],
#  ['sql', 'is', 'used', 'to', 'query', 'databases.'],
#  ['pandas', 'simplifies', 'data', 'analysis', 'tasks.'],
#  ['numpy', 'provides', 'efficient', 'numerical', 'operations.'],
#  ['data', 'visualization', 'helps', 'identify', 'trends.'],
#  ['the', 'software', 'engineer', 'deployed', 'the', 'application.'],
#  ['the', 'developer', 'fixed', 'the', 'production', 'bug.'],
#  ['cloud', 'computing', 'offers', 'scalable', 'infrastructure.'],
#  ['cybersecurity', 'protects', 'sensitive', 'information.'],
#  ['the', 'server', 'handled', 'thousands', 'of', 'requests.'],
#  ['the', 'doctor', 'examined', 'the', 'patient', 'carefully.'],
#  ['healthy', 'food', 'improves', 'overall', 'well-being.'],
#  ['regular', 'exercise', 'keeps', 'the', 'body', 'fit.'],
#  ['the', 'nurse', 'checked', 'the', "patient's", 'temperature.'],
#  ['the', 'hospital', 'installed', 'new', 'medical', 'equipment.'],
#  ['the', 'chef', 'prepared', 'spicy', 'indian', 'curry.'],
#  ['fresh', 'vegetables', 'are', 'rich', 'in', 'nutrients.'],
#  ['the', 'customer', 'ordered', 'biryani', 'for', 'dinner.'],
#  ['the', 'restaurant', 'served', 'delicious', 'desserts.'],
#  ['coffee', 'tastes', 'better', 'when', 'freshly', 'brewed.'],
#  ['the', 'football', 'team', 'won', 'the', 'championship.'],
#  ['basketball', 'players', 'trained', 'every', 'morning.'],
#  ['the', 'athlete', 'completed', 'the', 'marathon.'],
#  ['swimming', 'improves', 'cardiovascular', 'fitness.'],
#  ['the', 'coach', 'motivated', 'the', 'entire', 'team.'],
#  ['the', 'company', 'hired', 'a', 'new', 'manager.'],
#  ['employees', 'attended', 'the', 'weekly', 'meeting.'],
#  ['sales', 'increased', 'during', 'the', 'holiday', 'season.'],
#  ['marketing', 'campaigns', 'attracted', 'new', 'customers.'],
#  ['the', 'startup', 'secured', 'funding', 'from', 'investors.'],
#  ['heavy', 'rain', 'flooded', 'several', 'streets.'],
#  ['the', 'sun', 'shines', 'brightly', 'in', 'summer.'],
#  ['snow', 'covered', 'the', 'mountains', 'during', 'winter.'],
#  ['the', 'wind', 'moved', 'the', 'tree', 'branches.'],
#  ['people', 'enjoyed', 'the', 'pleasant', 'weather.'],
#  ['the', 'family', 'traveled', 'to', 'arizona', 'for', 'vacation.'],
#  ['children', 'played', 'in', 'the', 'playground.'],
#  ['the', 'movie', 'received', 'excellent', 'reviews.'],
#  ['music', 'makes', 'people', 'feel', 'relaxed.'],
#  ['technology', 'continues', 'to', 'evolve', 'rapidly.']]

# %%
vocabulary = sorted(list(set( word for words in tokenized_docs for word in words)))
vocabulary
# Out:
# ['a',
#  'algorithms.',
#  'analysis',
#  'animals.',
#  'application.',
#  'applications.',
#  'are',
#  'arizona',
#  'artificial',
#  'at',
#  'athlete',
#  'attended',
#  'attracted',
#  'barked',
#  'basketball',
#  'before',
#  'better',
#  'bird',
#  'biryani',
#  'board.',
#  'body',
#  'branches.',
#  'brewed.',
#  'brightly',
#  'bug.',
#  'built',
#  'campaigns',
#  'cardiovascular',
#  'carefully.',
#  'cat',
#  'championship.',
#  'checked',
#  'chef',
#  'children',
#  'class.',
#  'cloud',
#  'coach',
#  'coffee',
#  'company',
#  'completed',
#  'computing',
#  'continues',
#  'covered',
#  'curry.',
#  'customer',
#  'customers.',
#  'cybersecurity',
#  'data',
#  'data.',
#  'databases.',
#  'deep',
#  'delicious',
#  'deployed',
#  'desserts.',
#  'developer',
#  'dinner.',
#  'doctor',
#  'dog',
#  'during',
#  'easy',
#  'efficient',
#  'elephants',
#  'employees',
#  'engineer',
#  'enjoyed',
#  'entire',
#  'equipment.',
#  'every',
#  'evolve',
#  'examined',
#  'excellent',
#  'exercise',
#  'explained',
#  'family',
#  'feel',
#  'fit.',
#  'fitness.',
#  'fixed',
#  'flooded',
#  'food',
#  'football',
#  'for',
#  'fresh',
#  'freshly',
#  'from',
#  'funding',
#  'handled',
#  'healthy',
#  'heavy',
#  'helps',
#  'hired',
#  'holiday',
#  'homework',
#  'hospital',
#  'identify',
#  'improves',
#  'in',
#  'increased',
#  'indian',
#  'information.',
#  'infrastructure.',
#  'installed',
#  'intelligence',
#  'investors.',
#  'is',
#  'jungle.',
#  'keeps',
#  'land',
#  'largest',
#  'learn.',
#  'learning',
#  'lion',
#  'lives',
#  'loudly',
#  'machine',
#  'makes',
#  'manager.',
#  'many',
#  'marathon.',
#  'marketing',
#  'mat.',
#  'medical',
#  'meeting.',
#  'models',
#  'modern',
#  'morning.',
#  'motivated',
#  'mountains',
#  'moved',
#  'movie',
#  'music',
#  'nest',
#  'new',
#  'night.',
#  'notes',
#  'numerical',
#  'numpy',
#  'nurse',
#  'nutrients.',
#  'of',
#  'offers',
#  'on',
#  'operations.',
#  'ordered',
#  'overall',
#  'pandas',
#  'patient',
#  "patient's",
#  'people',
#  'played',
#  'players',
#  'playground.',
#  'pleasant',
#  'powers',
#  'prepared',
#  'production',
#  'professor',
#  'protects',
#  'provides',
#  'python',
#  'quality',
#  'query',
#  'rain',
#  'rapidly.',
#  'received',
#  'regular',
#  'relaxed.',
#  'requests.',
#  'require',
#  'restaurant',
#  'reviews.',
#  'rich',
#  'sales',
#  'sat',
#  'scalable',
#  'season.',
#  'secured',
#  'sensitive',
#  'served',
#  'server',
#  'several',
#  'shines',
#  'simplifies',
#  'snow',
#  'software',
#  'spicy',
#  'sql',
#  'startup',
#  'streets.',
#  'students',
#  'summer.',
#  'sun',
#  'swimming',
#  'tasks.',
#  'tastes',
#  'teacher',
#  'team',
#  'team.',
#  'technology',
#  'temperature.',
#  'the',
#  'their',
#  'thousands',
#  'to',
#  'trained',
#  'traveled',
#  'tree',
#  'tree.',
#  'trends.',
#  'used',
#  'vacation.',
#  'vegetables',
#  'visualization',
#  'weather.',
#  'weekly',
#  'well-being.',
#  'when',
#  'wind',
#  'winter.',
#  'won',
#  'wrote']

# %%
vocab_dict = {}
for  index, word in enumerate(vocabulary):
    vocab_dict[index] = word
vocab_dict
# Out:
# {0: 'a',
#  1: 'algorithms.',
#  2: 'analysis',
#  3: 'animals.',
#  4: 'application.',
#  5: 'applications.',
#  6: 'are',
#  7: 'arizona',
#  8: 'artificial',
#  9: 'at',
#  10: 'athlete',
#  11: 'attended',
#  12: 'attracted',
#  13: 'barked',
#  14: 'basketball',
#  15: 'before',
#  16: 'better',
#  17: 'bird',
#  18: 'biryani',
#  19: 'board.',
#  20: 'body',
#  21: 'branches.',
#  22: 'brewed.',
#  23: 'brightly',
#  24: 'bug.',
#  25: 'built',
#  26: 'campaigns',
#  27: 'cardiovascular',
#  28: 'carefully.',
#  29: 'cat',
#  30: 'championship.',
#  31: 'checked',
#  32: 'chef',
#  33: 'children',
#  34: 'class.',
#  35: 'cloud',
#  36: 'coach',
#  37: 'coffee',
#  38: 'company',
#  39: 'completed',
#  40: 'computing',
#  41: 'continues',
#  42: 'covered',
#  43: 'curry.',
#  44: 'customer',
#  45: 'customers.',
#  46: 'cybersecurity',
#  47: 'data',
#  48: 'data.',
#  49: 'databases.',
#  50: 'deep',
#  51: 'delicious',
#  52: 'deployed',
#  53: 'desserts.',
#  54: 'developer',
#  55: 'dinner.',
#  56: 'doctor',
#  57: 'dog',
#  58: 'during',
#  59: 'easy',
#  60: 'efficient',
#  61: 'elephants',
#  62: 'employees',
#  63: 'engineer',
#  64: 'enjoyed',
#  65: 'entire',
#  66: 'equipment.',
#  67: 'every',
#  68: 'evolve',
#  69: 'examined',
#  70: 'excellent',
#  71: 'exercise',
#  72: 'explained',
#  73: 'family',
#  74: 'feel',
#  75: 'fit.',
#  76: 'fitness.',
#  77: 'fixed',
#  78: 'flooded',
#  79: 'food',
#  80: 'football',
#  81: 'for',
#  82: 'fresh',
#  83: 'freshly',
#  84: 'from',
#  85: 'funding',
#  86: 'handled',
#  87: 'healthy',
#  88: 'heavy',
#  89: 'helps',
#  90: 'hired',
#  91: 'holiday',
#  92: 'homework',
#  93: 'hospital',
#  94: 'identify',
#  95: 'improves',
#  96: 'in',
#  97: 'increased',
#  98: 'indian',
#  99: 'information.',
#  100: 'infrastructure.',
#  101: 'installed',
#  102: 'intelligence',
#  103: 'investors.',
#  104: 'is',
#  105: 'jungle.',
#  106: 'keeps',
#  107: 'land',
#  108: 'largest',
#  109: 'learn.',
#  110: 'learning',
#  111: 'lion',
#  112: 'lives',
#  113: 'loudly',
#  114: 'machine',
#  115: 'makes',
#  116: 'manager.',
#  117: 'many',
#  118: 'marathon.',
#  119: 'marketing',
#  120: 'mat.',
#  121: 'medical',
#  122: 'meeting.',
#  123: 'models',
#  124: 'modern',
#  125: 'morning.',
#  126: 'motivated',
#  127: 'mountains',
#  128: 'moved',
#  129: 'movie',
#  130: 'music',
#  131: 'nest',
#  132: 'new',
#  133: 'night.',
#  134: 'notes',
#  135: 'numerical',
#  136: 'numpy',
#  137: 'nurse',
#  138: 'nutrients.',
#  139: 'of',
#  140: 'offers',
#  141: 'on',
#  142: 'operations.',
#  143: 'ordered',
#  144: 'overall',
#  145: 'pandas',
#  146: 'patient',
#  147: "patient's",
#  148: 'people',
#  149: 'played',
#  150: 'players',
#  151: 'playground.',
#  152: 'pleasant',
#  153: 'powers',
#  154: 'prepared',
#  155: 'production',
#  156: 'professor',
#  157: 'protects',
#  158: 'provides',
#  159: 'python',
#  160: 'quality',
#  161: 'query',
#  162: 'rain',
#  163: 'rapidly.',
#  164: 'received',
#  165: 'regular',
#  166: 'relaxed.',
#  167: 'requests.',
#  168: 'require',
#  169: 'restaurant',
#  170: 'reviews.',
#  171: 'rich',
#  172: 'sales',
#  173: 'sat',
#  174: 'scalable',
#  175: 'season.',
#  176: 'secured',
#  177: 'sensitive',
#  178: 'served',
#  179: 'server',
#  180: 'several',
#  181: 'shines',
#  182: 'simplifies',
#  183: 'snow',
#  184: 'software',
#  185: 'spicy',
#  186: 'sql',
#  187: 'startup',
#  188: 'streets.',
#  189: 'students',
#  190: 'summer.',
#  191: 'sun',
#  192: 'swimming',
#  193: 'tasks.',
#  194: 'tastes',
#  195: 'teacher',
#  196: 'team',
#  197: 'team.',
#  198: 'technology',
#  199: 'temperature.',
#  200: 'the',
#  201: 'their',
#  202: 'thousands',
#  203: 'to',
#  204: 'trained',
#  205: 'traveled',
#  206: 'tree',
#  207: 'tree.',
#  208: 'trends.',
#  209: 'used',
#  210: 'vacation.',
#  211: 'vegetables',
#  212: 'visualization',
#  213: 'weather.',
#  214: 'weekly',
#  215: 'well-being.',
#  216: 'when',
#  217: 'wind',
#  218: 'winter.',
#  219: 'won',
#  220: 'wrote'}

# %% [markdown]
# CBOW : Word2Vec learns from contexts, not from a list of words. The tokenized sentences provide those contexts.

# %%
CBOW_model = Word2Vec(
                         sentences = tokenized_docs,
                         vector_size = 20,
                         window = 2,
                         min_count = 1,
                         workers = 4,
                         sg = 0,
                         epochs = 100
                            
)

# %%
print(vocab_dict[0])  # Get the first word in the vocabulary
print(CBOW_model.wv[vocab_dict[0]])  # Get the vector representation of the first word in the vocabulary
print(CBOW_model.wv[vocab_dict[0]].shape)
# Out:
# a
# [-0.07833658 -0.05766207  0.08525775  0.11139072  0.01032691 -0.07017716
#   0.04661312  0.16327159 -0.00601829  0.03471612  0.298395    0.01194722
#   0.09531008 -0.0781086   0.16341259  0.05917379  0.3236748  -0.00282715
#  -0.04538698 -0.19156612]
# (20,)

# %% [markdown]
#  Most similar words

# %%
print(CBOW_model.wv.most_similar(vocab_dict[0], topn=5))  # Get the top 5 most similar words to the first word in the vocabulary
# Out:
# [('food', 0.9777576327323914), ('the', 0.9761860370635986), ('funding', 0.9739790558815002), ('models', 0.9738925695419312), ('in', 0.970725953578949)]

# %% [markdown]
# According to the learned embeddings, the word "a" is closest to these words

# %%
print(CBOW_model.wv.most_similar('developer'))
# Out:
# [('teacher', 0.9200341701507568), ('tastes', 0.9102075099945068), ('on', 0.8951680064201355), ('production', 0.8935964703559875), ('new', 0.89081871509552), ('land', 0.883186936378479), ('movie', 0.8811138272285461), ('keeps', 0.8809617757797241), ('better', 0.8809138536453247), ('powers', 0.8802021741867065)]

# %% [markdown]
# What does model.wv['cat'] return?
#
# - It returns the learned embedding vector for the word "cat". The vector is a fixed-length NumPy array (for example, 20, 100, or 300 dimensions depending on vector_size) that captures the word's semantic relationships learned during training.

# %% [markdown]
# "What does most_similar() do?"
#
# - It computes the cosine similarity between the embedding vector of the given word and all other word vectors, then returns the words with the highest similarity scores.

# %% [markdown]
#  Skip-Gram : Target --> Context

# %%
Skip_gram_model = Word2Vec(
                            sentences = tokenized_docs,
                            vector_size = 20,
                            window= 2,
                            min_count = 1,
                            workers = 4,
                            sg = 1,
                            epochs = 100
)

# %%
print(vocab_dict[12])
print(Skip_gram_model.wv[vocab_dict[12]])
print(Skip_gram_model.wv[vocab_dict[12]].shape)
# Out:
# attracted
# [ 0.00216719 -0.14888506  0.14822114  0.13801865 -0.12862976 -0.16751602
#  -0.10229963  0.19575937 -0.03661655  0.19996859  0.41783965 -0.02453698
#   0.2140562   0.06545345  0.21823159  0.15597697  0.27611595 -0.04197236
#  -0.10730129 -0.21156158]
# (20,)

# %%
print(Skip_gram_model.wv.most_similar('developer'))
# Out:
# [('teacher', 0.9714382290840149), ('production', 0.9651934504508972), ('tastes', 0.9635637402534485), ('on', 0.961057186126709), ('land', 0.9609005451202393), ('shines', 0.9606525301933289), ('bug.', 0.9586114883422852), ('the', 0.957831084728241), ('secured', 0.9569399356842041), ('from', 0.9565020799636841)]

# %%
print(Skip_gram_model.wv.most_similar(vocab_dict[12], topn=5))  # Get the top 5 most similar words to the 13th word in the vocabulary
# Out:
# [('ordered', 0.9828206896781921), ('handled', 0.9782223105430603), ('efficient', 0.9769939184188843), ('brightly', 0.9768334627151489), ('morning.', 0.9767633080482483)]
